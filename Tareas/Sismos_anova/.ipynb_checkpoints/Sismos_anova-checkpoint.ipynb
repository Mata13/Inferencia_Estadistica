# %% [markdown]
# <font color = 'DodgerBlue'>
# <font size = 5>
#
# **TAREA. Sismos - ANOVA**

# %% [markdown]
# <font color = 'LightSeaGreen'>
# <font size = 3>
#
# La tabla [sismos.csv](https://github.com/scidatmath2020/Inferencia_Estadistica_2024/blob/main/data/muestra_aleatoria_sismos.csv) consiste de una **muestra aleatoria** de tamaño 5000 de la información tomada del Servicio Sismológico Nacional de todos los sismos registrados desde el 1 de enero de 1900 hasta las 19:40pm (hora de México DF) del 23 de diciembre de 2023. Realiza con ella un **ANOVA** para:
#
# 1. Verificar que la magnitud **promedio** mensual de los sismos en México varía durante todo el año. Es decir, que prácticamente todos los meses tienen su propio nivel de magnitud de sismicidad.
#
# 2. Verificar que la magnitud **promedio** mensual de los sismos fuertes (arriba de 6.5) en México es la misma durante todo el año. Es decir, que si te fijas en sismos fuertes ($> 6.5$), todos los meses tienen la misma magnitud **promedio**.
#
# Hay que aplicar una **ANOVA** sin importar la magnitud, tu columna de clasificación va ser el mes en el que ocurrió el sismo. Después, tienes que aplicar un filtro para crear una nueva tabla (puede ser en Excel) y obtener los que tienen magnitud arriba de 6.5 y aplicarle el **ANOVA** a la columna de clasificación "mes".
#
# La idea es verificar que cada mes tiene su propia magnitud de sismicidad con el **ANOVA** (sismos en general). Pero, en cuanto a sismos fuertes, no hay un mes que tienen sismos más fuertes que otro, para tumbar el mito de que en septiempre hay sismos más fuertes.
#
# ---

# %% [markdown]
# <font color = 'deepskyblue'>
# <font size = 5>
#
# Librerías y lectura de los datos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from plotnine import *
import pingouin as pg
import scipy.stats as stats
import random
from distfit import distfit

# Para la pruebas de gaussianidad
from scipy.stats import shapiro, kstest, norm, anderson, jarque_bera

# Para que muestre todas las columnas de los dataframes
pd.set_option('display.max_columns', None)

# %%
# Importamos los datos que vamos a usar
data_sismos = pd.read_csv("Data/muestra_aleatoria_sismos.csv")

# Muestra las primeras rows del dataframe
data_sismos.head()
# Out:
#         Fecha      Hora  Magnitud  Latitud  Longitud  Profundidad  \
# 0  17/03/2021  08:54:31       3.0  17.8555  -98.7023         46.3
# 1  01/05/2017  00:46:29       3.5  15.0717  -93.5760         20.0
# 2  21/06/1999  03:48:16       3.8  16.3100  -98.3800         36.0
# 3  09/09/2023  04:16:04       3.4  16.8195  -99.3495          8.5
# 4  01/02/2018  18:38:52       3.6  16.5247  -94.9210         57.4
#
#                  Referencia de localizacion   Fecha UTC  Hora UTC   Estatus  \
# 0           37 km al NOROESTE de TLAPA, GRO  17/03/2021  14:54:31  revisado
# 1     79 km al SUROESTE de PIJIJIAPAN, CHIS  01/05/2017  05:46:29  revisado
# 2  35 km al OESTE de PINOTEPA NACIONAL, OAX  21/06/1999  08:48:16  revisado
# 3        5 km al NORESTE de SAN MARCOS, GRO  09/09/2023  10:16:04  revisado
# 4   11 km al NOROESTE de UNION HIDALGO, OAX  02/02/2018  00:38:52  revisado
#
#    Mes  Mes_nombre
# 0    3       marzo
# 1    5        mayo
# 2    6       junio
# 3    9  septiembre
# 4    2     febrero

# %%
print("------------------------------------------")

# Muestra las dimensiones del dataframe
print(f"Dimensiones del dataframe: {data_sismos.shape}")

print("------------------------------------------")

#Muestra las columnas del dataframe
print(data_sismos.columns)

print("------------------------------------------")

# Buscamos valores nulos en la columna de 'Magnitud'
print(f"Valores nulos en la columna 'Magnitud': {data_sismos['Magnitud'].isna().sum()}")

print("------------------------------------------")

# Valores máximo y mínimo de la columna 'Magnitud'
print(f"Magnitud mínima: {data_sismos['Magnitud'].min()}")

print(f"Magnitud máxima: {data_sismos['Magnitud'].max()}")

print("------------------------------------------")
# Out:
# ------------------------------------------
# Dimensiones del dataframe: (5000, 12)
# ------------------------------------------
# Index(['Fecha', 'Hora', 'Magnitud', 'Latitud', 'Longitud', 'Profundidad',
#        'Referencia de localizacion', 'Fecha UTC', 'Hora UTC', 'Estatus', 'Mes',
#        'Mes_nombre'],
#       dtype='object')
# ------------------------------------------
# Valores nulos en la columna 'Magnitud': 0
# ------------------------------------------
# Magnitud mínima: 0.6
# Magnitud mínima: 6.9
# ------------------------------------------

# %%
# Histograma de los datos para ver su distribución
(
    ggplot(data = data_sismos) + geom_histogram(mapping = aes(x = "Magnitud"), fill = "deepskyblue", color = "white", binwidth = 0.5)
)

# %%
# Extraemos las columnas 'Mes' y 'Magnitud'
sismos = data_sismos[['Mes', 'Magnitud']]

# Se muestran los primeros rows del dataframe
sismos.head()
# Out:
#    Mes  Magnitud
# 0    3       3.0
# 1    5       3.5
# 2    6       3.8
# 3    9       3.4
# 4    2       3.6

# %%
# Ordenamos los datos por mes desde el 1 hasta el 12
sismos = sismos.sort_values('Mes')

sismos
# Out:
#       Mes  Magnitud
# 1335    1       3.0
# 1332    1       1.2
# 4935    1       3.2
# 4934    1       4.1
# 4953    1       3.6
# ...   ...       ...
# 3083   12       3.7
# 3109   12       3.6
# 659    12       3.4
# 4995   12       3.9
# 28     12       2.8
#
# [5000 rows x 2 columns]

# %% [markdown]
# <font color = 'deepskyblue'>
# <font size = 5>
#
# ---
#
# Paso 0) Identificación de parámetros

# %%
# Obtenemos los tamaños de cada grupo
sismos.groupby('Mes').size()
# Out:
# Mes
# 1     449
# 2     392
# 3     422
# 4     355
# 5     392
# 6     373
# 7     356
# 8     384
# 9     466
# 10    473
# 11    480
# 12    458
# dtype: int64

# %%
# Calculamos la media y desviación de cada grupo
sismos.groupby('Mes').agg(['mean', 'std'])
# Out:
#      Magnitud
#          mean       std
# Mes
# 1    3.648107  0.388969
# 2    3.580357  0.425344
# 3    3.621564  0.400812
# 4    3.661972  0.366833
# 5    3.647959  0.377969
# 6    3.610456  0.434436
# 7    3.611517  0.384864
# 8    3.584115  0.402061
# 9    3.494635  0.694984
# 10   3.497463  0.693121
# 11   3.584167  0.434089
# 12   3.564629  0.437035

# %%
# Histograma de los datos para ver su distribución
(
    ggplot(data = sismos) + geom_histogram(mapping = aes(x = "Magnitud"), fill = "deepskyblue", color = "white", binwidth = 0.5)
)

# %%
# Gráfico Q-Q
stats.probplot(sismos.Magnitud, dist = "norm", plot = plt)
plt.title("Gráfico Q-Q")
plt.grid(True)
plt.show()

# %% [markdown]
# <font color = 'deepskyblue'>
# <font size = 5>
#
# ---
#
# Paso 1) Prueba de normalidad

# %%
# Prueba de gaussianidad
def gaussian_test(lista):
    shapiro_test = shapiro(lista)
    ks_test = kstest(lista,"norm",args=(np.mean(lista),np.std(lista,ddof=1)))
    jb_test = jarque_bera(lista)
    p_valores = [shapiro_test.pvalue, ks_test.pvalue,jb_test.pvalue] 
#    previos = [x<0.05 for x in p_valores]
    rech = ["Rechazar H0","No rechazar H0"]
    significados = ["Hay buena probabilidad de que NO es gaussiana",
                    "Hay buena probabilidad de que SÍ es gaussiana"]
        
    resultados = pd.DataFrame({"Prueba":["SW","KS","JB"],
     "p_valor":p_valores,
     "Resultado":[rech[0] if x < 0.05 else rech[1] for x in p_valores],
     "Interpretación":[significados[0] if x < 0.05 else significados[1] for x in p_valores]
    })
    
    anderson_test = anderson(lista,dist="norm")
    est_A = anderson_test.statistic
    resultados_anderson = pd.DataFrame({"Estadístico A":5*[est_A],#,"","","","",""],
                                        "Significancia":anderson_test.significance_level,
                                        "Valor_crítico":anderson_test.critical_values,
                                        "Resultado":[rech[0] if est_A > anderson_test.critical_values[i] else rech[1] for i in range(5)],
                                        "Interpretación":[significados[0] if est_A > anderson_test.critical_values[i] else significados[1] for i in range(5)]})
    return  resultados, resultados_anderson

# %%
# Prueba de gaussianidad
prueba_gauss, prueba_anderson = gaussian_test(sismos.Magnitud)

# %%
# Resultados
prueba_gauss
# Out:
#   Prueba       p_valor    Resultado  \
# 0     SW  3.720869e-53  Rechazar H0
# 1     KS  7.706516e-79  Rechazar H0
# 2     JB  0.000000e+00  Rechazar H0
#
#                                   Interpretación
# 0  Hay buena probabilidad de que NO es gaussiana
# 1  Hay buena probabilidad de que NO es gaussiana
# 2  Hay buena probabilidad de que NO es gaussiana

# %%
# Resultados
prueba_anderson
# Out:
#    Estadístico A  Significancia  Valor_crítico    Resultado  \
# 0     127.718427           15.0          0.576  Rechazar H0
# 1     127.718427           10.0          0.655  Rechazar H0
# 2     127.718427            5.0          0.786  Rechazar H0
# 3     127.718427            2.5          0.917  Rechazar H0
# 4     127.718427            1.0          1.091  Rechazar H0
#
#                                   Interpretación
# 0  Hay buena probabilidad de que NO es gaussiana
# 1  Hay buena probabilidad de que NO es gaussiana
# 2  Hay buena probabilidad de que NO es gaussiana
# 3  Hay buena probabilidad de que NO es gaussiana
# 4  Hay buena probabilidad de que NO es gaussiana

# %% [markdown]
# <font color = 'LightSeaGreen'>
# <font size = 3>
#
# Con el método gráfico y la **prueba de gaussianidad**, podemos decir que la **muestra** de sismos no es **gaussiana**.
#
# Procedemos hacer una **transformación** de los **datos** para tratar de obtener la **gaussianidad** y poder seguir trabajando con la **ANOVA**.
#
# ---

# %%
# Construimos un modelo
modelo_automatico = distfit(todf = True) # un modelo que convierte los resultados en un dataframe

# Ajustamos el modelo y le damos de comer datos
modelo_automatico.fit_transform(sismos.Magnitud)

# Crea un resumen en una tabla de lo que obtuvo
tabla_resultados = modelo_automatico.summary
tabla_resultados
# Out:
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [norm      ] [0.00 sec] [RSS: 21.6258] [loc=3.589 scale=0.477]
# [distfit] >INFO> [expon     ] [0.00 sec] [RSS: 35.4869] [loc=0.600 scale=2.989]
# [distfit] >INFO> [pareto    ] [0.00 sec] [RSS: 35.4869] [loc=-268435455.400 scale=268435456.000]
# [distfit] >INFO> [dweibull  ] [0.05 sec] [RSS: 25.7204] [loc=3.600 scale=0.240]
# [distfit] >INFO> [t         ] [0.14 sec] [RSS: 20.1294] [loc=3.619 scale=0.279]
# [distfit] >INFO> [genextreme] [0.08 sec] [RSS: 24.0843] [loc=3.379 scale=0.597]
# [distfit] >INFO> [gamma     ] [0.05 sec] [RSS: 22.0063] [loc=-6.426 scale=0.025]
# [distfit] >INFO> [lognorm   ] [0.00 sec] [RSS: 21.6258] [loc=-131071.400 scale=131074.989]
# [distfit] >INFO> [beta      ] [0.14 sec] [RSS: 21.4754] [loc=-85.307 scale=93.523]
# [distfit] >INFO> [uniform   ] [0.00 sec] [RSS: 33.904] [loc=0.600 scale=6.300]
# [distfit] >INFO> [loggamma  ] [0.02 sec] [RSS: 21.3445] [loc=-0.192 scale=1.562]
# [distfit] >INFO> [norm      ] [0.51 sec] [RSS: 21.6258] [loc=3.589 scale=0.477]
# [distfit] >INFO> [expon     ] [0.51 sec] [RSS: 35.4869] [loc=0.600 scale=2.989]
# [distfit] >INFO> [pareto    ] [0.51 sec] [RSS: 35.4869] [loc=-268435455.400 scale=268435456.000]
# [distfit] >INFO> [dweibull  ] [0.51 sec] [RSS: 25.7204] [loc=3.600 scale=0.240]
# [distfit] >INFO> [t         ] [0.46 sec] [RSS: 20.1294] [loc=3.619 scale=0.279]
# [distfit] >INFO> [genextreme] [0.31 sec] [RSS: 24.0843] [loc=3.379 scale=0.597]
# [distfit] >INFO> [gamma     ] [0.23 sec] [RSS: 22.0063] [loc=-6.426 scale=0.025]
# [distfit] >INFO> [lognorm   ] [0.17 sec] [RSS: 21.6258] [loc=-131071.400 scale=131074.989]
# [distfit] >INFO> [beta      ] [0.17 sec] [RSS: 21.4754] [loc=-85.307 scale=93.523]
# [distfit] >INFO> [uniform   ] [0.03 sec] [RSS: 33.904] [loc=0.600 scale=6.300]
# [distfit] >INFO> [loggamma  ] [0.03 sec] [RSS: 21.3445] [loc=-0.192 scale=1.562]
# [distfit] >INFO> Compute confidence intervals [parametric]
#           name      score          loc          scale  \
# 0            t  20.129367     3.619101       0.279176
# 1     loggamma  21.344496     -0.19172       1.561994
# 2         beta  21.475401   -85.307089      93.523377
# 3         norm   21.62576      3.58886        0.47693
# 4      lognorm   21.62578    -131071.4  131074.988859
# 5        gamma  22.006325    -6.425783       0.024995
# 6   genextreme    24.0843     3.378866       0.596559
# 7     dweibull  25.720379          3.6       0.240153
# 8      uniform   33.90397          0.6            6.3
# 9        expon  35.486894          0.6        2.98886
# 10      pareto  35.486894 -268435455.4    268435456.0
#
#                                         arg  \
# 0                      (2.847285859616724,)
# 1                     (11.746154336803729,)
# 2   (1763.9021516151033, 91.88698653137465)
# 3                                        ()
# 4                 (3.6386096208819052e-06,)
# 5                      (400.6593307451775,)
# 6                    (0.16829475081793932,)
# 7                     (0.4959522142363785,)
# 8                                        ()
# 9                                        ()
# 10                     (89811987.69135953,)
#
#                                                params  \
# 0   (2.847285859616724, 3.619100933106927, 0.27917...
# 1   (11.746154336803729, -0.19171988258124933, 1.5...
# 2   (1763.9021516151033, 91.88698653137465, -85.30...
# 3            (3.5888600000000004, 0.4769296598032041)
# 4   (3.6386096208819052e-06, -131071.4, 131074.988...
# 5   (400.6593307451775, -6.425783058523065, 0.0249...
# 6   (0.16829475081793932, 3.3788662435111707, 0.59...
# 7   (0.4959522142363785, 3.5999999999999996, 0.240...
# 8                            (0.6, 6.300000000000001)
# 9                           (0.6, 2.9888600000000003)
# 10     (89811987.69135953, -268435455.4, 268435456.0)
#
#                                                 model bootstrap_score  \
# 0   <scipy.stats._distn_infrastructure.rv_continuo...               0
# 1   <scipy.stats._distn_infrastructure.rv_continuo...               0
# 2   <scipy.stats._distn_infrastructure.rv_continuo...               0
# 3   <scipy.stats._distn_infrastructure.rv_continuo...               0
# 4   <scipy.stats._distn_infrastructure.rv_continuo...               0
# 5   <scipy.stats._distn_infrastructure.rv_continuo...               0
# 6   <scipy.stats._distn_infrastructure.rv_continuo...               0
# 7   <scipy.stats._distn_infrastructure.rv_continuo...               0
# 8   <scipy.stats._distn_infrastructure.rv_continuo...               0
# 9   <scipy.stats._distn_infrastructure.rv_continuo...               0
# 10  <scipy.stats._distn_infrastructure.rv_continuo...               0
#
#    bootstrap_pass    color
# 0            None  #e41a1c
# 1            None  #e41a1c
# 2            None  #377eb8
# 3            None  #4daf4a
# 4            None  #984ea3
# 5            None  #ff7f00
# 6            None  #ffff33
# 7            None  #a65628
# 8            None  #f781bf
# 9            None  #999999
# 10           None  #999999

# %%
# Se muestra la gráfica con el score para ver qué distribución podemos tomar
modelo_automatico.plot_summary()
plt.show()
# %matplotlib inline
# Out:
# [distfit] >INFO> Ploting Summary.

# %% [markdown]
# <font color = 'LightSeaGreen'>
# <font size = 3>
#
# ---
#
# **Transformación** de los **datos** usando logaritmo natural.

# %%
# Transformamos los datos con logaritmo natural y agregamos la nueva columna al dataframe
sismos['Magnitud_log_transformado'] = np.log(sismos.Magnitud)

sismos
# Out:
#       Mes  Magnitud  Magnitud_log_transformado
# 1335    1       3.0                   1.098612
# 1332    1       1.2                   0.182322
# 4935    1       3.2                   1.163151
# 4934    1       4.1                   1.410987
# 4953    1       3.6                   1.280934
# ...   ...       ...                        ...
# 3083   12       3.7                   1.308333
# 3109   12       3.6                   1.280934
# 659    12       3.4                   1.223775
# 4995   12       3.9                   1.360977
# 28     12       2.8                   1.029619
#
# [5000 rows x 3 columns]

# %%
# Histograma de los datos transformados para ver su distribución
(
    ggplot(data = sismos) + geom_histogram(mapping = aes(x = "Magnitud_log_transformado"), fill = "salmon", color = "white", binwidth = 0.5)
)

# %%
# Gráfico Q-Q
stats.probplot(sismos.Magnitud_log_transformado, dist = "norm", plot = plt)
plt.title("Gráfico Q-Q")
plt.grid(True)
plt.show()

# %%
# Prueba de gaussianidad a los datos transformados
prueba_gauss, prueba_anderson = gaussian_test(sismos.Magnitud_log_transformado)

# %%
# Resultados prueba gauss
prueba_gauss
# Out:
#   Prueba        p_valor    Resultado  \
# 0     SW   2.563459e-67  Rechazar H0
# 1     KS  4.275925e-146  Rechazar H0
# 2     JB   0.000000e+00  Rechazar H0
#
#                                   Interpretación
# 0  Hay buena probabilidad de que NO es gaussiana
# 1  Hay buena probabilidad de que NO es gaussiana
# 2  Hay buena probabilidad de que NO es gaussiana

# %%
# Resultados prueba anderson
prueba_anderson
# Out:
#    Estadístico A  Significancia  Valor_crítico    Resultado  \
# 0     269.127251           15.0          0.576  Rechazar H0
# 1     269.127251           10.0          0.655  Rechazar H0
# 2     269.127251            5.0          0.786  Rechazar H0
# 3     269.127251            2.5          0.917  Rechazar H0
# 4     269.127251            1.0          1.091  Rechazar H0
#
#                                   Interpretación
# 0  Hay buena probabilidad de que NO es gaussiana
# 1  Hay buena probabilidad de que NO es gaussiana
# 2  Hay buena probabilidad de que NO es gaussiana
# 3  Hay buena probabilidad de que NO es gaussiana
# 4  Hay buena probabilidad de que NO es gaussiana

# %% [markdown]
# <font color = 'LightSeaGreen'>
# <font size = 3>
#
# Por la prueba de **gaussianidad** y el método gráfico, la **transformación** de los **datos** con logaritmo natural, no se obtuvo **gaussianidad**.
#
# ---

# %% [markdown]
# <font color = 'LightSeaGreen'>
# <font size = 3>
#
# **Transformación** de los **datos** con raiz cuadrada.

# %%
# Transformamos los datos con raiz cuadrada y agregamos la nueva columna al dataframe
sismos['Magnitud_sqrt2_transformado'] = np.sqrt(sismos['Magnitud'])

sismos
# Out:
#       Mes  Magnitud  Magnitud_log_transformado  Magnitud_sqrt2_transformado
# 1335    1       3.0                   1.098612                     1.732051
# 1332    1       1.2                   0.182322                     1.095445
# 4935    1       3.2                   1.163151                     1.788854
# 4934    1       4.1                   1.410987                     2.024846
# 4953    1       3.6                   1.280934                     1.897367
# ...   ...       ...                        ...                          ...
# 3083   12       3.7                   1.308333                     1.923538
# 3109   12       3.6                   1.280934                     1.897367
# 659    12       3.4                   1.223775                     1.843909
# 4995   12       3.9                   1.360977                     1.974842
# 28     12       2.8                   1.029619                     1.673320
#
# [5000 rows x 4 columns]

# %%
# Histograma de los datos transformados para ver su distribución
(
    ggplot(data = sismos) + geom_histogram(mapping = aes(x = "Magnitud_sqrt2_transformado"), fill = "salmon", color = "white", binwidth = 0.5)
)

# %%
# Gráfico Q-Q
stats.probplot(sismos.Magnitud_sqrt2_transformado, dist = "norm", plot = plt)
plt.title("Gráfico Q-Q")
plt.grid(True)
plt.show()

# %%
# Prueba de gaussianidad a los datos sqrt2-transformados
prueba_gauss, prueba_anderson = gaussian_test(sismos.Magnitud_sqrt2_transformado)

# %%
# Resultados prueba gauss
prueba_gauss
# Out:
#   Prueba        p_valor    Resultado  \
# 0     SW   4.048548e-60  Rechazar H0
# 1     KS  2.741270e-107  Rechazar H0
# 2     JB   0.000000e+00  Rechazar H0
#
#                                   Interpretación
# 0  Hay buena probabilidad de que NO es gaussiana
# 1  Hay buena probabilidad de que NO es gaussiana
# 2  Hay buena probabilidad de que NO es gaussiana

# %%
# Resultados prueba anderson
prueba_anderson
# Out:
#    Estadístico A  Significancia  Valor_crítico    Resultado  \
# 0     182.696792           15.0          0.576  Rechazar H0
# 1     182.696792           10.0          0.655  Rechazar H0
# 2     182.696792            5.0          0.786  Rechazar H0
# 3     182.696792            2.5          0.917  Rechazar H0
# 4     182.696792            1.0          1.091  Rechazar H0
#
#                                   Interpretación
# 0  Hay buena probabilidad de que NO es gaussiana
# 1  Hay buena probabilidad de que NO es gaussiana
# 2  Hay buena probabilidad de que NO es gaussiana
# 3  Hay buena probabilidad de que NO es gaussiana
# 4  Hay buena probabilidad de que NO es gaussiana

# %% [markdown]
# <font color = 'LightSeaGreen'>
# <font size = 3>
#
# Por la prueba de **gaussianidad** y el método gráfico, la **transformación** de los **datos** con raíz cuadrada, no se obtuvo **gaussianidad**.
#
# ---

# %% [markdown]
# <font color = 'LightSeaGreen'>
# <font size = 3>
#
# **Transformación** de los **datos** con np.square.

# %%
# Transformamos los datos con np.square y agregamos la nueva columna al dataframe
sismos['Magnitud_square_transformado'] = np.square(sismos.Magnitud)

sismos
# Out:
#       Mes  Magnitud  Magnitud_log_transformado  Magnitud_sqrt2_transformado  \
# 1335    1       3.0                   1.098612                     1.732051
# 1332    1       1.2                   0.182322                     1.095445
# 4935    1       3.2                   1.163151                     1.788854
# 4934    1       4.1                   1.410987                     2.024846
# 4953    1       3.6                   1.280934                     1.897367
# ...   ...       ...                        ...                          ...
# 3083   12       3.7                   1.308333                     1.923538
# 3109   12       3.6                   1.280934                     1.897367
# 659    12       3.4                   1.223775                     1.843909
# 4995   12       3.9                   1.360977                     1.974842
# 28     12       2.8                   1.029619                     1.673320
#
#       Magnitud_square_transformado
# 1335                          9.00
# 1332                          1.44
# 4935                         10.24
# 4934                         16.81
# 4953                         12.96
# ...                            ...
# 3083                         13.69
# 3109                         12.96
# 659                          11.56
# 4995                         15.21
# 28                            7.84
#
# [5000 rows x 5 columns]

# %%
# Histograma de los datos transformados para ver su distribución
(
    ggplot(data = sismos) + geom_histogram(mapping = aes(x = "Magnitud_square_transformado"), fill = "salmon", color = "white", binwidth = 0.5)
)

# %%
# Gráfico Q-Q
stats.probplot(sismos.Magnitud_square_transformado, dist = "norm", plot = plt)
plt.title("Gráfico Q-Q")
plt.grid(True)
plt.show()

# %%
# Prueba de gaussianidad a los datos square-transformados
prueba_gauss, prueba_anderson = gaussian_test(sismos.Magnitud_square_transformado)

# %%
# Resultados prueba gauss
prueba_gauss
# Out:
#   Prueba       p_valor    Resultado  \
# 0     SW  3.044581e-46  Rechazar H0
# 1     KS  2.029278e-46  Rechazar H0
# 2     JB  0.000000e+00  Rechazar H0
#
#                                   Interpretación
# 0  Hay buena probabilidad de que NO es gaussiana
# 1  Hay buena probabilidad de que NO es gaussiana
# 2  Hay buena probabilidad de que NO es gaussiana

# %%
# Resultados prueba anderson
prueba_anderson
# Out:
#    Estadístico A  Significancia  Valor_crítico    Resultado  \
# 0      82.500324           15.0          0.576  Rechazar H0
# 1      82.500324           10.0          0.655  Rechazar H0
# 2      82.500324            5.0          0.786  Rechazar H0
# 3      82.500324            2.5          0.917  Rechazar H0
# 4      82.500324            1.0          1.091  Rechazar H0
#
#                                   Interpretación
# 0  Hay buena probabilidad de que NO es gaussiana
# 1  Hay buena probabilidad de que NO es gaussiana
# 2  Hay buena probabilidad de que NO es gaussiana
# 3  Hay buena probabilidad de que NO es gaussiana
# 4  Hay buena probabilidad de que NO es gaussiana

# %% [markdown]
# <font color = 'LightSeaGreen'>
# <font size = 3>
#
# Por la prueba de **gaussianidad** y el método gráfico, la **transformación** de los **datos** con logaritmo natural, no se obtuvo **gaussianidad**.
#
# ---

# %% [markdown]
# <font color = 'LightSeaGreen'>
# <font size = 3>
#
# **Transformación** de los **datos** con cube

# %%
# Transformamos los datos con cube y agregamos la nueva columna al dataframe

sismos['Magnitud_cube_transformado'] = np.power(sismos['Magnitud'], 3)

sismos
# Out:
#       Mes  Magnitud  Magnitud_log_transformado  Magnitud_sqrt2_transformado  \
# 1335    1       3.0                   1.098612                     1.732051
# 1332    1       1.2                   0.182322                     1.095445
# 4935    1       3.2                   1.163151                     1.788854
# 4934    1       4.1                   1.410987                     2.024846
# 4953    1       3.6                   1.280934                     1.897367
# ...   ...       ...                        ...                          ...
# 3083   12       3.7                   1.308333                     1.923538
# 3109   12       3.6                   1.280934                     1.897367
# 659    12       3.4                   1.223775                     1.843909
# 4995   12       3.9                   1.360977                     1.974842
# 28     12       2.8                   1.029619                     1.673320
#
#       Magnitud_square_transformado  Magnitud_cube_transformado
# 1335                          9.00                      27.000
# 1332                          1.44                       1.728
# 4935                         10.24                      32.768
# 4934                         16.81                      68.921
# 4953                         12.96                      46.656
# ...                            ...                         ...
# 3083                         13.69                      50.653
# 3109                         12.96                      46.656
# 659                          11.56                      39.304
# 4995                         15.21                      59.319
# 28                            7.84                      21.952
#
# [5000 rows x 6 columns]

# %%
# Gráfico Q-Q
stats.probplot(sismos.Magnitud_cube_transformado, dist = "norm", plot = plt)
plt.title("Gráfico Q-Q")
plt.grid(True)
plt.show()

# %%
# Prueba de gaussianidad a los datos transformados
prueba_gauss, prueba_anderson = gaussian_test(sismos.Magnitud_cube_transformado)

# %%
prueba_gauss
# Out:
#   Prueba       p_valor    Resultado  \
# 0     SW  1.965323e-53  Rechazar H0
# 1     KS  8.977111e-65  Rechazar H0
# 2     JB  0.000000e+00  Rechazar H0
#
#                                   Interpretación
# 0  Hay buena probabilidad de que NO es gaussiana
# 1  Hay buena probabilidad de que NO es gaussiana
# 2  Hay buena probabilidad de que NO es gaussiana

# %%
prueba_anderson
# Out:
#    Estadístico A  Significancia  Valor_crítico    Resultado  \
# 0      94.748528           15.0          0.576  Rechazar H0
# 1      94.748528           10.0          0.655  Rechazar H0
# 2      94.748528            5.0          0.786  Rechazar H0
# 3      94.748528            2.5          0.917  Rechazar H0
# 4      94.748528            1.0          1.091  Rechazar H0
#
#                                   Interpretación
# 0  Hay buena probabilidad de que NO es gaussiana
# 1  Hay buena probabilidad de que NO es gaussiana
# 2  Hay buena probabilidad de que NO es gaussiana
# 3  Hay buena probabilidad de que NO es gaussiana
# 4  Hay buena probabilidad de que NO es gaussiana

# %% [markdown]
# <font color = 'LightSeaGreen'>
# <font size = 3>
#
# Por la prueba de **gaussianidad** y el método gráfico, la **transformación** de los **datos** con el cubo, no se obtuvo **gaussianidad**.
#
# ---

# %% [markdown]
# <font color = 'LightSeaGreen'>
# <font size = 3>
#
# **Transformación** de los **datos** con exp.

# %%
# Transformamos los datos con cube y agregamos la nueva columna al dataframe

sismos['Magnitud_exp_transformado'] = np.exp(sismos['Magnitud'])

sismos
# Out:
#       Mes  Magnitud  Magnitud_log_transformado  Magnitud_sqrt2_transformado  \
# 1335    1       3.0                   1.098612                     1.732051
# 1332    1       1.2                   0.182322                     1.095445
# 4935    1       3.2                   1.163151                     1.788854
# 4934    1       4.1                   1.410987                     2.024846
# 4953    1       3.6                   1.280934                     1.897367
# ...   ...       ...                        ...                          ...
# 3083   12       3.7                   1.308333                     1.923538
# 3109   12       3.6                   1.280934                     1.897367
# 659    12       3.4                   1.223775                     1.843909
# 4995   12       3.9                   1.360977                     1.974842
# 28     12       2.8                   1.029619                     1.673320
#
#       Magnitud_square_transformado  Magnitud_cube_transformado  \
# 1335                          9.00                      27.000
# 1332                          1.44                       1.728
# 4935                         10.24                      32.768
# 4934                         16.81                      68.921
# 4953                         12.96                      46.656
# ...                            ...                         ...
# 3083                         13.69                      50.653
# 3109                         12.96                      46.656
# 659                          11.56                      39.304
# 4995                         15.21                      59.319
# 28                            7.84                      21.952
#
#       Magnitud_exp_transformado
# 1335                  20.085537
# 1332                   3.320117
# 4935                  24.532530
# 4934                  60.340288
# 4953                  36.598234
# ...                         ...
# 3083                  40.447304
# 3109                  36.598234
# 659                   29.964100
# 4995                  49.402449
# 28                    16.444647
#
# [5000 rows x 7 columns]

# %%
# Gráfico Q-Q
stats.probplot(sismos.Magnitud_exp_transformado, dist = "norm", plot = plt)
plt.title("Gráfico Q-Q")
plt.grid(True)
plt.show()

# %%
# Prueba de gaussianidad a los datos transformados
prueba_gauss, prueba_anderson = gaussian_test(sismos.Magnitud_exp_transformado)

# %%
prueba_gauss
# Out:
#   Prueba        p_valor    Resultado  \
# 0     SW   3.125016e-80  Rechazar H0
# 1     KS  3.976872e-183  Rechazar H0
# 2     JB   0.000000e+00  Rechazar H0
#
#                                   Interpretación
# 0  Hay buena probabilidad de que NO es gaussiana
# 1  Hay buena probabilidad de que NO es gaussiana
# 2  Hay buena probabilidad de que NO es gaussiana

# %%
prueba_anderson
# Out:
#    Estadístico A  Significancia  Valor_crítico    Resultado  \
# 0     366.195144           15.0          0.576  Rechazar H0
# 1     366.195144           10.0          0.655  Rechazar H0
# 2     366.195144            5.0          0.786  Rechazar H0
# 3     366.195144            2.5          0.917  Rechazar H0
# 4     366.195144            1.0          1.091  Rechazar H0
#
#                                   Interpretación
# 0  Hay buena probabilidad de que NO es gaussiana
# 1  Hay buena probabilidad de que NO es gaussiana
# 2  Hay buena probabilidad de que NO es gaussiana
# 3  Hay buena probabilidad de que NO es gaussiana
# 4  Hay buena probabilidad de que NO es gaussiana

# %% [markdown]
# <font color = 'LightSeaGreen'>
# <font size = 3>
#
# Por la prueba de **gaussianidad** y el método gráfico, la **transformación** de los **datos** con exp, no se obtuvo **gaussianidad**.
#
# ---
