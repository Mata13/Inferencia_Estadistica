# %% [markdown]
# <font color='IndianRed'>
# <font size=9>
#
# **Curso Inferencia Estadística**

# %% [markdown]
# <font color = 'DodgerBlue'>
# <font size = 5>
#
# **Repaso - Geometría analítica**

# %% [markdown]
# <font size = 3>
#
# Antes de avanzar, es necesario recordar los cursos de Geometría Analítica: toda recta en el plano es una ecuación de la forma
#
# $$y = m x + b$$
#
# donde:
#
# * $b$ se conoce como *ordenada al origen* y es el valor sobre el eje Y en que en la recta lo atraviesa. En **regresión lineal** se le llama *intercepto*.
#
# * $m$ se conoce como *pendiente de la recta* y se identifica como la tangente inversa del ángulo que hace la recta con el eje X.
#
# En cristiano: $m$ mide la inclinación de la recta. $m = tan^{-1}(\alpha)$. También en regresión lineal se llama pendiente.
#
# Si $m > 0$ la recta va hacia arriba; si $m < 0$ la recta va hacia abajo; si $m = 0$, la recta es horizontal.
#
# Por lo tanto, **hallar la ecuación de una recta equivale a hallar los valores de $m$ y $b$**.
#
# Observa la interacción del archivo **geogebra-recta_pendiente_origen.ggb** en GEOGEBRA, para visualizar el comportamiento de la peniente y la ordenada al origen. Ese archivo se encuentra en el repositorio [hecho con geogebra](https://github.com/scidatmath2020/Inferencia-Estad-stica-2022/blob/main/geogebra-recta_pendiente_origen.ggb).
#
# ---

# %% [markdown]
# <font color = 'DodgerBlue'>
# <font size = 5>
#
# **Regresiones lineales**

# %% [markdown]
# <font size = 3>
#
# Las **regresiones** son maneras de *modelar* una **característica** medida utilizando otras, también medidas, de la misma **muestra** con el objetivo de crear predicciones. Esto es: si $X_1,X_2,...,X_n,X_{n+1}$ son algunas de las columnas de la tabla, encontrar una función $f$ tal que $X_{n+1}=f(X_1,X_2,...,X_n)$.
#
# En cristiano: **¿será posible explicar el comportamiento de una de las características a través del conocimiento de otras?**, y si es afirmativo, **¿cómo es esa dependencia?**
#
# Bajo la idea anterior, decimos que las **características** $X_1,X_2,...,X_n$ son **explicativas** o **predictoras** y la característica $X_{n+1}$ es la **variable objetivo** o **a predecir**.
#
# ---

# %% [markdown]
# <font color = 'DodgerBlue'>
# <font size = 5>
#
# **Regresión lineal (simple)**

# %% [markdown]
# <font size = 3>
#
# En esta sección revisaremos un problema de **regresión** muy sencillo conocido como **regresión lineal**. Observemos la siguiente nube de puntos:
#
# <img src = "Img/im016.png">
#
# Debido a su forma, vale preguntarse cuál será la recta que mejor se aproxime, en algún sentido, a todos los puntos al mismo tiempo.
#
# Observemos varias rectas graficadas con la nube de puntos. ¿Cuál dirías que es la que más se *ajusta* a todos los puntos al mismo tiempo?
#
# <img src = "Img/im017.png">
#
# De esta manera, sean $X$ y $Y$ dos características de tu **población**.
#
# Decimos que el modelo que explica a $Y$ a través de $X$ es lineal si tenemos razones para pensar que existen números $\beta_0$ y $\beta_1$ tales que $Y=\beta_0+\beta_1X+\varepsilon$ donde $\varepsilon$ es una **variable aleatoria gaussiana** con **media** 0 (un ruido blanco).
#
# **Observación:**
#
# Para no confundir la expresión anterior, veamos cómo se relaciona con la expresión clásica de la ecuación de una recta.
#
# $$Y = mX + b$$
#
# $$\Rightarrow Y = b + mX$$
#
# $$\Rightarrow Y = \beta_{0} + \beta_{1}X$$
#
# > ⚠️ **Nota importante: $\beta_{0}$ y $\beta_{1}$ son valores poblacionales (no los conoces). Los los estimas con los estimas con los mínimos cuadrados, calculas el $b_{0}$ y el $b_{1}$.**
#
# ---

# %% [markdown]
# <font color = 'DodgerBlue'>
# <font size = 5>
#
# **Mínimos cuadrados**

# %% [markdown]
# <font size = 3>
#
# Recordar el objetivo: tenemos una lista de parejas de puntos (cada renglón) $(x_1,y_1),(x_2,y_2),...,(x_n,y_n)$. Los graficamos como nube de puntos y buscamos la recta que mejor aproxime, en cierto sentido, a todos los puntos al mismo tiempo.
#
# En principio, cualquier recta $y = mx + b$ es una recta que podemos tomar como aproximación, que sea buena o mala es otra cosa. Por lo tanto, a cada $x_i$ se le asignan dos números: el $y_i$ (que es un valor que conocemos) y el $\hat{y_i} = mx_i + b$, que es el valor que nos da la recta para ese número $x_i$.
#
# * **Predicciones.** Son los valores $\hat{y_1},\hat{y_2},...,\hat{y_n}$. Es decir, los valores que *la recta predice*.
#
# * **Residuos.** ¿Qué tanto se equivocó la recta? Recordemos: la recta le asigna a $x_i$ el valor $\hat{y_i}$. Pero el valor verdadero que acompaña a $x_i$ es $y_i$. Los residuos son los errores que la recta cometió: $\varepsilon_i=y_i-\hat{y_i}$.
#
# Dicho esto, lo que buscamos es minimizar los residuos al mismo tiempo. Esto es: hallar $m$ y $b$ tales que $$\sum_{i=1}^n(y_i-\hat{y_i})^2$$ es lo menor posible.
#
# Es decir, dadas tus observaciones $(x_1,y_1),(x_2,y_2),...,(x_n,y_n)$ hallar $m$ y $b$ tales $$\sum_{i=1}^n(y_i-mx_i-b)^2$$ sea mínima.
#
# Esto es lo que se conoce como **problema de los mínimos cuadrados.**
#
# Se puede demostrar fácilmente que el $m$ y $b$ que resuelven este problema son $$m=\frac{\sum(x_i-\overline{x})(y_i-\overline{y})}{\sum(x_i-\overline{x})^2}\mbox{ y }b=\overline{y}-m\overline{x}$$
#
# **Observación:**
#
# - $\sum(x_i-\overline{x})(y_i-\overline{y})$ es la **correlación** $\rho_{X,Y}$.
#
# - $\sum(x_i-\overline{x})^2$ viene siendo la **varianza** $Var(X,Y)$.
#
# Por lo tanto tenemos el siguiente resultado:
#
# Si $(X_1,Y_1),(X_2,Y_2),...,(X_n,Y_n)$ son una muestra de tamaño $n$ de la característica $(X,Y)$ (es decir, $n$ renglones de tu tabla tomando solo las columnas $X$ y $Y$), entonces los estimadores para $\beta_0$ y $\beta_1$ de la recta de mínimos cuadrados son $$b_1=\frac{\sum(X_i-\overline{X})(Y_i-\overline{Y})}{\sum(X_i-\overline{X})^2}\,\,\mbox{ y
# }\,\,b_0=\overline{Y}-b_1\overline{X}$$
#
# Con esto obtenemos la recta que mejor se aproxima a los datos.
#
# ---

# %% [markdown]
# <font color = 'LightSeaGreen'>
# <font size = 3>
#
# **Ejemplo 1. Datos**

# %% [markdown]
# <font color = 'LightSeaGreen'>
# <font size = 3>
#
# En un experimento donde se quería estudiar la asociación entre consumo de sal y presión arterial, se asignó aleatoriamente a algunos individuos una cantidad diaria constante de sal en su dieta, y al cabo de un mes se los midió la tensión arterial media. Algunos resultados fueron los siguientes:
#
# $X$(sal, en g)|$Y$(Presión, en mm de Hg)
# :--:|:--:
# 1.8	|100
# 2.2	|98
# 3.5	|110
# 4.0	|110
# 4.3	|112
# 5.0	|120
#
# En **Python** esto es
#
# ```python
# ################################################################
# ########################    EN PYTHON    #######################
# ################################################################
#
# import pandas as pd
# import numpy as np
# import statsmodels.api as sm
# from plotnine import *
#
# presion = pd.DataFrame({
#     "sal": [1.8, 2.2, 3.5, 4.0, 4.3, 5.0],
#     "tension": [100, 98, 110, 110, 112, 120]
# })
#
# ################################################################
# ```
# Observemos la siguiente gráfica de los datos:
# ```python
# ################################################################
# ########################    EN PYTHON    #######################
# ################################################################
#
# (ggplot(data=presion) +
#      geom_smooth(mapping=aes(x="sal",y="tension"),method="lm",color="red") +
#      geom_point(mapping=aes(x="sal",y="tension"), color="blue")
# )
#
# ################################################################
# ```
#
#
# <img src = "Img/im016.png">
#
# ---

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from plotnine import *
pd.set_option('display.max_columns', None)

# %%
presion = pd.DataFrame({
    "sal": [1.8, 2.2, 3.5, 4.0, 4.3, 5.0],
    "tension": [100, 98, 110, 110, 112, 120]
})

presion
# Out:
#    sal  tension
# 0  1.8      100
# 1  2.2       98
# 2  3.5      110
# 3  4.0      110
# 4  4.3      112
# 5  5.0      120

# %% [markdown]
# <font color = 'LightSeaGreen'>
# <font size = 3>
#
# Queremos explicar la tensión a través de la sal.
#
# La recta de **regresión** OLS (Ordinary Least Squares, o Mínimos Cuadrados Ordinario).
#
# Graficamos usando ggplot.
#
# - *geom_smooth* genera la recta de **regresión** con el **método** *lm*.
# - *geom_point* hace la gráfica de los puntos.

# %%
(ggplot(data = presion) +
     geom_smooth(mapping = aes(x = "sal", y = "tension"), method = "lm", color = "red") + # recta de regresión
     geom_point(mapping = aes(x = "sal", y = "tension"), color = "deepskyblue") # gráfica de los puntos
)

# %% [markdown]
# <font color = 'DodgerBlue'>
# <font size = 5>
#
# ---
#
# **Regresión lineal simple en Python**

# %% [markdown]
# <font size = 3>
#
# En **Python**, para realizar **regresiones lineales simples** contamos con función ``OLS(y,X)`` de ``statsmodels.api `` (recordemos que previamente esta paquetería fue cargada bajo el alias de ``sm``):
#
# ```python
# ################################################################
# ########################    EN PYTHON    #######################
# ################################################################
#
# # Agregar una constante para la intercepción
# X = sm.add_constant(tabla["columna predictora"])
# y = tabla["columna a predecir"]
#
# # Realizar la regresión lineal
# modelo = sm.OLS(y, X).fit()
#
# ################################################################
# ```
#
# Haciendo ``modelo.summary()`` veremos un resumen general de los resultados obtenidos. Los coeficientes $b_0$ y $b_1$ se obtienen, en ese orden, mediante ``modelo.params``
#
# ---

# %%
# Agregar una constante para la intercepción
X = sm.add_constant(presion["sal"]) # columna predictora
y = presion["tension"] # columna objetivo

# %%
X
# Out:
#    const  sal
# 0    1.0  1.8
# 1    1.0  2.2
# 2    1.0  3.5
# 3    1.0  4.0
# 4    1.0  4.3
# 5    1.0  5.0

# %%
y
# Out:
# 0    100
# 1     98
# 2    110
# 3    110
# 4    112
# 5    120
# Name: tension, dtype: int64

# %%
# Realizar la regresión lineal
modelo = sm.OLS(y, X).fit()

# %%
# Resumen general de los resultados
modelo.summary()
# Out:
# /home/zick13/anaconda3/envs/curso_estadistica/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                tension   R-squared:                       0.934
# Model:                            OLS   Adj. R-squared:                  0.918
# Method:                 Least Squares   F-statistic:                     56.95
# Date:                Tue, 21 Jan 2025   Prob (F-statistic):            0.00165
# Time:                        12:33:32   Log-Likelihood:                -12.377
# No. Observations:                   6   AIC:                             28.75
# Df Residuals:                       4   BIC:                             28.34
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
# Resultados ---> b = 86.37, m = 6.33
modelo.params
# Out:
# const    86.370787
# sal       6.335350
# dtype: float64

# %% [markdown]
# <font color = 'DodgerBlue'>
# <font size = 5>
#
# ---
#
# **Efectividad de la recta de regresión**

# %% [markdown]
# <font size = 3>
#
# En general, dadas las **características** $X$ y $Y$ y al menos dos **observaciones** (es decir, dos renglones de la tabla), **siempre será posible hallar la recta de regresión lineal**. Sin embargo, esto no nos dice si la recta es un buen modelo o no. Es decir, si la **inferencia** que hagamos a partir de ella será confiable o no.
#
# Una forma de verificar si nuestras características $X$ y $Y$ obedecen a un modelo lineal es el **coeficiente de determinación $R^2$**.
#
# Este se define a través de la **identidad de suma de cuadrados** (muy parecida a la del **ANOVA**):
#
# $$\underbrace{\sum_{i=1}^n(Y_i-\overline{Y})^2}_{SS_{Total}}=\underbrace{\sum_{i=1}^n(\hat{Y_i}-\overline{Y})^2}_{SS_{Regresión}}+\underbrace{\sum_{i=1}^n(Y_i-\hat{Y_i})^2}_{SS_{Error}}$$
#
# Como hemos dicho, la filosofía es que $SS_{Error}$ sea lo mínimo posible y, si es chica entonces la variación total de los datos originales viene fuertemente explicada por la variación de los datos de nuestas predicciones.
#
# Se define el **coeficiente de determinación** como $$R^2=\frac{SS_{Regresión}}{SS_{Total}}$$
#
# Cuanto más cerca esté el $R^2$ a 1, es mejor nuestra **regresión**. Es decir, el modelo si se ajusta bien a una naturaleza lineal.
#
# Y si $R^2$ es próximo a 0, entonces no existe modelo lineal que relacione a $X$ con $Y$ y por lo tanto la recta de **regresión lineal** no nos sirve para nada.
#
# ---

# %% [markdown]
# <font color = 'DodgerBlue'>
# <font size = 5>
#
# **R^2 en Python**

# %% [markdown]
# <font size = 3>
#
# En **Python**, simplemente hacemos ``modelo.rsquared`` para obtener el coeficiente de determinación.
#
# ```python
# ################################################################
# ########################    EN PYTHON    #######################
# ################################################################
#
# modelo.rsquared
#
# ################################################################
# ```

# %%
modelo.rsquared
# Out:
# np.float64(0.9343685275003523)

# %% [markdown]
# <font color = 'LightSeaGreen'>
# <font size = 3>
#
# Como el valor es cercano a 1, entonces la recta nos sirve.
#
# ---

# %% [markdown]
# <font color = 'DodgerBlue'>
# <font size = 5>
#
# **Intervalos de confianza de los coeficientes en la regresión lineal simple**

# %% [markdown]
# <font size = 3>
#
# Recordemos que $b_0$ y $b_1$ dependen de la **muestra**, por lo que a su vez son **variables aleatorias** que nos siven para estimar $\beta_0$ y $\beta_1$.
#
# Bajo ciertos supuestos que veremos en la siguiente sección (**Regresión múltiple**), podemos encontrar **intervalos de confianza** para $\beta_0$ y $\beta_1$:
#
# $$\beta_0:\,\,\,\left(b_0-t_{n-2,1-\alpha/2}S\sqrt{\frac{1}{n}+\frac{\overline{X}^2}{(n-1)S_X ^2}},b_0+t_{n-2,1-\alpha/2}S\sqrt{\frac{1}{n}+\frac{\overline{X}^2}{(n-1)S_X ^2}}\right)$$
#
# $$\beta_1:\,\,\,\left(b_1-t_{n-2,1-\alpha/2}\frac{S}{S_X\sqrt{n-1}},b_1-t_{n-2,1+\alpha/2}\frac{S}{S_X\sqrt{n-1}}\right)$$
#
# donde $S$ es la **desviación muestral** de los errores y $S_X$ es la **desviación muestral** de la variable $X$.
#
# ---

# %% [markdown]
# <font color = 'DodgerBlue'>
# <font size = 5>
#
# **Intervalos de confianza de los coeficientes en Python**

# %% [markdown]
# <font size = 3>
#
# En **Python** los intervalos de confianza al $100*(1-\alpha)$% vienen dados por ``modelo.conf_int(alpha)``
#
# ---

# %% [markdown]
# <font color = 'LightSeaGreen'>
# <font size = 3>
#
# **Ejemplo 1. Intervalos de confianza de los coeficientes**
#
# ```python
# ################################################################
# ########################    EN PYTHON    #######################
# ################################################################
#
# modelo.conf_int(alpha = 0.95)
#
# ################################################################
# ```

# %%
modelo.conf_int(alpha = 0.01) # 99%
# Out:
#                0           1
# const  72.272638  100.468935
# sal     2.470062   10.200638

# %% [markdown]
# <font color = 'DodgerBlue'>
# <font size = 5>
#
# ---
#
# **Significancia de la pendiente $\beta_1$**

# %% [markdown]
# <font size = 3>
#
# Cuando decimos que $Y$ se explica linealmente por $X$, implícitamente estamos diciendo que en el modelo (**poblacional**)
#
# $$Y=\beta_0+\beta_1X+\varepsilon$$
#
# tenemos $\beta_1\neq0$ (ya que si $\beta_1=0$, entonces $Y$ no dependería de $X$, y por lo tanto la variación de $Y$ únicamente depende de $\varepsilon$ que es totalmente azar).
#
# Por lo tanto se plante el contraste
#
# $$\begin{array}{l}H_0:\beta_1=0 \mbox{ (la pendiente es igual a cero)}   \\H_1:\beta_1\neq0 \mbox{ (la pendiente no es cero)} \end{array}$$
#
# se quiere entregar evidencia de la **hipótesis alternativa**.
#
# En este caso, una vez calculado el $p$-valor correspondiente, tenemos la regla de decisión:
#
# |$p$-valor|Descripción|Significado|
# |:--:|:--|:--|
# |$<0.05$|Tenemos evidencia suficiente para rechazar $H_0$|Sí hay efectos de $X$ sobre $Y$|
# |$>0.1$|No tenemos evidencia suficiente para rechazar $H_0$|No hay efectos de $X$ sobre $Y$|
# en otro caso||Necesitamos mas información|
#
# El $p$-valor viene dado en ``modelo.summary()``

# %%
modelo.summary()
# Out:
# /home/zick13/anaconda3/envs/curso_estadistica/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 6 samples were given.
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                tension   R-squared:                       0.934
# Model:                            OLS   Adj. R-squared:                  0.918
# Method:                 Least Squares   F-statistic:                     56.95
# Date:                Tue, 21 Jan 2025   Prob (F-statistic):            0.00165
# Time:                        12:33:32   Log-Likelihood:                -12.377
# No. Observations:                   6   AIC:                             28.75
# Df Residuals:                       4   BIC:                             28.34
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# <font color = 'DodgerBlue'>
# <font size = 5>
#
# ---
#
# **Predicciones en la regresión lineal simple**

# %% [markdown]
# <font size = 3>
#
# Nuevamente, bajo ciertos supuestos que veremos en la siguiente sección (**Regresión múltiple**), la utilidad de las **regresiones lineales** radica en que nos sirven para realizar **predicciones**. Es decir, si llega un nuevo **dato** de la **variable** $X$, digamos $x_0$, podemos utilizar el modelo calculado a partir de la tabla original para encontrar el valor de $Y$ en $x_0$: $$Y|_{x_0}=b_0+b_1x_0$$
#
# En otras palabras, nos puede interesar el valor **medio** de la variable de respuesta cuando un valor $x_0$ no ha sido considerado en la **muestra**, o el valor de la variable respuesta también cuando un valor $x_0$ no ha sido considerado en la muestra.
#
# Para ambos valores usamos como estimación a $b_0+b_1x_0$.
#
# ---

# %% [markdown]
# <font color = 'LightSeaGreen'>
# <font size = 3>
#
# ****Ejemplo 1. Predicciones****

# %% [markdown]
# <font color = 'LightSeaGreen'>
# <font size = 3>
#
# Suponiendo que a un paciente se le administra una dosis de sal de 4.5, ¿cuál va a ser su presión promedio y el intervalo de confianza de su presión promedio al 95%? ¿Cuál va a ser su presión y el intervalo de confianza para su presión?
#
# ```python
# ################################################################
# ########################    EN PYTHON    #######################
# ################################################################
#
# # Nuevo dato para predicción
# new_data = pd.DataFrame({'sal': [4.5]})
# new_data = sm.add_constant(new_data)  # Agregar constante
#
# # Predicción con intervalo de confianza
# pred_conf = modelo.get_prediction(new_data).summary_frame(alpha=0.05)  # 95% confidence interval
#
# # Predicción con intervalo de predicción
# pred_pred = modelo.get_prediction(new_data).summary_frame(alpha=0.05, obs=True)  # 95% prediction interval
#
# # Mostrar resultados
# print("Intervalo de confianza:")
# print(pred_conf[['mean', 'mean_ci_lower', 'mean_ci_upper']])
#
# print("\nIntervalo de predicción:")
# print(pred_pred[['mean', 'obs_ci_lower', 'obs_ci_upper']])
#
# ################################################################
# ```

# %%
# Nuevo dato para predicción
new_data = pd.DataFrame({'sal': [4.5]})
new_data = sm.add_constant(new_data, has_constant = 'add')  # Agregar constante

# %%
# Predicción con intervalo de confianza
pred_conf = modelo.get_prediction(new_data).summary_frame(alpha = 0.05)  # 95% confidence interval
pred_conf
# Out:
#          mean   mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  \
# 0  114.879862  1.287892     111.304101     118.455622    107.484328
#
#    obs_ci_upper
# 0    122.275396

# %%
# Mostrar resultados
print("------------------------------------------")

print("Intervalo de confianza para la media:")
print(pred_conf[['mean', 'mean_ci_lower', 'mean_ci_upper']])

print("------------------------------------------")

print("\nIntervalo de predicción:") # observado
print(pred_conf[['mean', 'obs_ci_lower', 'obs_ci_upper']])

print("------------------------------------------")
# Out:
# ------------------------------------------
# Intervalo de confianza para la media:
#          mean  mean_ci_lower  mean_ci_upper
# 0  114.879862     111.304101     118.455622
# ------------------------------------------
#
# Intervalo de predicción:
#          mean  obs_ci_lower  obs_ci_upper
# 0  114.879862    107.484328    122.275396
# ------------------------------------------

# %% [markdown]
# <font color = 'Brown'>
# <font size = 4>
#
# ---
#
# **Notas**

# %% [markdown]
# <font color = 'DarkRed'>
# <font size = 3>
#
# - Si tienes una recta completamente vertical, la pendiente será $m = \pm \infty$.
# - Las **regresiones lineales** son las respuestas a la pregunta **"¿será cierto que existe una dependencia de una de las columnas sobre las demás?, y en caso afirmativo, ¿cómo es esa dependencia?**. Esto es una dependencia funcional.
# - Las columnas **predictoras** son las columnas con las que quieres explicar.
# - La columna **objetivo** es aquella columna a la que quieres explicar.
# - Las **regresiones lineales** te permiten hacer predicciones.
# - Generalmente, las columnas **predictoras** y **objetivo** las propones tú, aunque a veces la naturaleza del fenómeno es quien te va a decir cuáles son las columnas **predictoras** y **objetivo**.
# - El error cometido es la desviación estándar.
# - La **regresión logística** se estudia en **estadística multivariante** y **Machine Learning**.
# - En la **regresión lineal simple** solamente vamos a tener dos columnas, una de ellas será la columna **objetivo** y la otra será la columna **explicativa**, y requieres que esa relación que existe sea de tipo lineal. Es decir, que sea de la forma $y = mx + b$.
# - La idea intuitiva de la **regresión lineal** es que la línea recta se acerque a todos los puntos al mismo tiempo.
# - Si hay una alta **correlación** positiva o negativa entre dos **características** implica que se puede hacer una **regresión lineal** para ver su comportamiento. Es decir, si $\rho (X,Y)$ es muy próxima a $1$ o $-1$, es porque esto $Y = \beta_{0} + \beta_{1}X$ se va a cumplir.
# - Si la **correlación** es muy próxima a 0 se puede observar una nube de puntos sin un patrón o estructura definida, como un cielo estrellado.
# - El ruido blanco son pequeñas perturbaciones que no puedes controlar.
# - La única manera de que el error sea $= 0 $, es que todos los puntos estén sobre la recta.
# - El error se pone al cuadrado para que sea derivable y le puedas aplicar los métodos de optimización.
# - EL valor absoluto no es derivale.
# - Mientras tengas más de dos **datos** (renglones), la recta de **regresión** siempre la vas a poder hacer, no habrá problema por el tamaño de la **muestra**.
# - Los **valores atípicos** te afectan las **medias** o **promedios** y eso tambié afectan los errores.
