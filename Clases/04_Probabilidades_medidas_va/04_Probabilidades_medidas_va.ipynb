# %% [markdown]
# <font color='IndianRed'>
# <font size=9>
#
# **Curso Inferencia Estadística**

# %% [markdown]
# <font color = 'DodgerBlue'>
# <font size = 5>
#
# **Medidas de las variables aleatorias**

# %% [markdown]
# <font color = 'Black'>
# <font size = 3>
#
# ---
#
# Una **variable aleatoria** es una función que asigna un número real a cada resultado de un experimento aleatorio.
#
# Se clasifica en:
#
# - **Discretas**: Toman valores específicos y contables. Ejemplo: número de caras al lanzar dos monedas.
#
# - **Continuas**: Toman cualquier valor dentro de un intervalo. Ejemplo: la altura de una persona.
#
# **Explicación Conceptual:**
#
# Imagina que estás realizando un experimento como lanzar un dado. Una variable aleatoria es una forma de traducir los posibles resultados de ese experimento (1, 2, 3, ...) en números que podamos analizar.

# %% [markdown]
# <font color = 'LightSeaGreen'>
# <font size = 3>
#
# ---
#
# **Ejemplos.**
#
# - **Variable Discreta**: Sea $X$ el número de caras al lanzar dos monedas. Los valores posibles de $X$ son $0$, $1$, o $2$.
#
# - **Variable Continua**: Sea $Y$ la temperatura diaria en tu ciudad. $Y$ puede tomar valores como $25.3^\circ$C o $30.7^\circ$C.

# %% [markdown]
# <font color = 'Black'>
# <font size = 3>
#
# ---
#
# **Variables Aleatorias Independientes**
#
# Decimos que dos **variables** son **independientes** si saber el resultado de una no te dice nada sobre la otra.
#
# Por ejemplo, lanzar un dado y lanzar una moneda son eventos independientes: el número del dado no afecta si sale cara o cruz.
#
# **Definición Matemática**
#
# Dos **variables aleatorias** $X$ e $Y$ son **independientes** si:
# $$
# P(X \leq x, Y \leq y) = P(X \leq x) \cdot P(Y \leq y)
# $$
#
# La probabilidad de que sucedan dos **eventos** $P(X \leq x, Y \leq y)$ es igual al producto de las probabilidades $P(X \leq x) \cdot P(Y \leq y)$.
#
# ---

# %% [markdown]
# <font color = 'LightSeaGreen'>
# <font size = 3>
#
# **Ejemplos.**
#
# - Si $X$ es el resultado de lanzar un dado y $Y$ es el resultado de lanzar una moneda:
# $$
# P(X = 4 \, \text{y} \, Y = \text{cara}) = P(X = 4) \cdot P(Y = \text{cara}) = \frac{1}{6} \cdot \frac{1}{2} = \frac{1}{12}
# $$

# %% [markdown]
# <font color = 'DodgerBlue'>
# <font size = 5>
#
# **Esperanza**

# %% [markdown]
# <font color = 'Black'>
# <font size = 3>
#
# ---
#
# **Esperanza Matemática**
#
# La **esperanza** es el "promedio esperado" o el valor típico que obtendrías si repitieras el experimento muchas veces.
#
# La **esperanza matemática** (o valor esperado) de una variable aleatoria es:
#
# - Para una variable discreta:
#   $$
#   E[X] = \sum_{x \in \text{Rango}(X)} x \cdot P(X = x)
#   $$
# - Para una variable continua:
#   $$
#   E[X] = \int_{-\infty}^\infty x \cdot f_X(x) \, dx
#   $$
#   Esta integral es la manera análoga de calcular el centro de masa de una lámina de densidad uniforme. Esto viene del centro de gravedad pero visto desde la teoría de la medida. A partir de la Teoría de la Medida te llevas esos conceptos a la física o conceptos probabilísticos.
#
# ---

# %% [markdown]
# <font color = 'LightSeaGreen'>
# <font size = 3>
#
# **Ejemplos.**
#
# - $X$ es el número que sale al lanzar un dado de 6 caras. Entonces la **esperanza** es:
#
# $$
# \begin{aligned}
# E(X) &= 1 \cdot P(X = 1) + 2 \cdot P(X = 2) + 3 \cdot P(X = 3) + 4 \cdot P(X = 4) + 5 \cdot P(X = 5) + 6 \cdot P(X = 6) \\
# &= 1 \cdot \left(\frac{1}{6}\right) + 2 \cdot \left(\frac{1}{6}\right) + 3 \cdot \left(\frac{1}{6}\right) + 4 \cdot \left(\frac{1}{6}\right) + 5 \cdot \left(\frac{1}{6}\right) + 6 \cdot \left(\frac{1}{6}\right) \\
# &= \left(\frac{1}{6}\right) \cdot \left(1 + 2 + 3 + 4 + 5 + 6\right) \\
# &= \frac{21}{6} \\
# &= \frac{7}{2} \\
# &= 3.5
# \end{aligned}
# $$
#
# No siempre tienen una interpretación como tal, ya que en este caso el valor 3.5 no sale en la cara de un dado.

# %% [markdown]
# <font color = 'Black'>
# <font size = 3>
#
# ---
#
# **Uniforme continua** en el intervalo $[a,b]$: $f(x) = \frac{1}{b - a}$ cuando $x$ está en $[a,b]$. La $f(x)$ es la función de densidad.
#
# Entonces, la **esperanza** es:
#
# $$E[X] = \int_{-\infty}^{\infty} xf(x) dx,$$
#
# Como conocemos el valor de $f(x)$, entonces queda como:
#
# $$E[X] = \int_{-\infty}^{\infty} xf(x) dx = \int_{a}^{b} x \left(\frac{1}{b - a}\right) dx = \frac{a + b}{2}.$$
#
# - Observar que la $f(x)$ fuera del intervalo vale $0$.
# - El punto medio del intervalo es $\frac{a+b}{2}$.
# - Qué es lo que nos está diciendo la **esperanza** de una **distribución uniforme continua**? Nos dice que la gran mayoría de los valores que tú vayas seleccionando de manera uniforme, van a caer al rededor de la mitad del intervalo.
#
# La **varianza** es:
#
# $$Var(X) = \frac{(b-a)^2}{12}$$
#
# La **desviación** es:
#
# $$\sigma(X) = \sqrt{ \frac{(b-a)^2}{12}} = \frac{b-a}{2\sqrt{3}}$$
#
# ---

# %% [markdown]
# <font color = 'Black'>
# <font size = 3>
#
# Una **Poisson** ($\lambda$):
#
# $$f(x) = \frac{e^{-\lambda}\lambda^x}{x!}$$
#
# - Recordar que la **Poisson** nos dice cuántos éxitos voy a tener en un periodo de tiempo, sabiendo que en ese periodo de tiempo tengo $\lambda$ éxitos.
# - La **Poisson** es discreta.
#
# La **esperanza**
#
# $$E[X] = \sum_{x=0}^\infty xf(x) = \sum_{x=0}^\infty x \frac{e^{-\lambda}\lambda^x}{x!} = e^{-\lambda} \sum_{x=0}^\infty \frac{\lambda^x}{(x-1)!} = \lambda e^{-\lambda} \sum_{x=0}^\infty \frac{\lambda^x}{x!} = \lambda e^{-\lambda} e^{\lambda} = \lambda$$
#
# - Recordar que $\lambda$ es cuántos éxtos hay en un periodo de tiempo.
# - La **esperanza** de la v.a. **Poisson** es la $\lambda$.
# - Coincide la **esperanza** de la v.a. es el valor típico que estamos esperando si realizas el experimento muchas veces.
# - La **esperanza** es una medida del valor más representativo.
# - La **esperanza** es el análogo al promedio de una muestra.
#
# ---

# %% [markdown]
# <font color = 'Black'>
# <font size = 3>
#
# Si $X$ es **binomial** en $n$ y parámetro de éxito $p$, significa que si yo tomo una muestra de tamaño $n$, quiero preguntarme cuántos elementos cumplen una característica, sabiendo que la probabilidad de que uno lo cumpla es $p$. Entonces, quién sería la **esperanza**?
#
# $$E[X] = p \cdot n$$
#
# Dem:
#
# Completar prueba
#
# ---

# %% [markdown]
# <font color = 'DodgerBlue'>
# <font size = 5>
#
# **Varianza y Desviación Estándar**

# %% [markdown]
# <font color = 'Black'>
# <font size = 3>
#
# - La **varianza** mide cuánto se alejan los resultados del promedio. Si los valores están muy dispersos, la **varianza** será grande.
# - La **desviación estádar** es una medida más intuitiva de esa dispersión, ya que usa las mismas unidades que la variable.

# %% [markdown]
# <font color = 'Black'>
# <font size = 3>
#
# **Definición Matemática**
#
# - La **varianza** mide qué tan dispersos están los valores de $X$ respecto a su promedio:
#   $$
#   \text{Var}(X) = E[(X - E[X])^2] = E[X^2] - (E[X])^2
#   $$
# - La **desviación estándar** es la raíz cuadrada de la varianza:
#   $$
#   \text{Desv}(X) = \sqrt{\text{Var}(X)}
#   $$
#
# ---

# %% [markdown]
# <font color = 'LightSeaGreen'>
# <font size = 3>
#
# **Ejemplo**
#
# - Para $X$ (caras en dos monedas), $E[X] = 1$:
#
# 1. Calculamos $E[X^2]$:
#    $$
#    E[X^2] = 0^2 \cdot \frac{1}{4} + 1^2 \cdot \frac{1}{2} + 2^2 \cdot \frac{1}{4} = 1.5
#    $$
# 2. La varianza es:
#    $$
#    \text{Var}(X) = E[X^2] - (E[X])^2 = 1.5 - 1^2 = 0.5
#    $$
# 3. La desviación estándar es:
#    $$
#    \text{Desv}(X) = \sqrt{0.5} \approx 0.71
#    $$
#
# ---

# %% [markdown]
# <font color = 'DodgerBlue'>
# <font size = 5>
#
# **Covarianza**

# %% [markdown]
# <font color = 'Black'>
# <font size = 3>
#
# La covarianza mide si dos variables tienden a aumentar o disminuir juntas:
# - **Positiva**: Cuando una sube, la otra también sube.
# - **Negativa**: Cuando una sube, la otra baja.
# - **Cero**: No hay relación lineal entre las variables.

# %% [markdown]
# <font color = 'Black'>
# <font size = 3>
#
# **Definición Matemática**
#
# La **covarianza** entre dos variables $X$ e $Y$ es:
# $$
# \text{Cov}(X, Y) = E[(X - E[X])(Y - E[Y])] = E[XY] - E[X]E[Y]
# $$
#
# - La **covarianza** es el producto interno en el espacio $L^2$.
# - La **covarianza**  te va a medir qué tan relacionadas linealmente están tus variables aleatorias.
# - Si $X$ y $Y$, la covarianza es positiva, entonces $Y = aX + B$ con $a > 0$.
#
# ---

# %% [markdown]
# <font color = 'LightSeaGreen'>
# <font size = 3>
#
# **Ejemplo**
#
# Si $X$ es el resultado de lanzar una moneda y $Y$ el resultado de lanzar un dado, entonces $X$ e $Y$ son independientes y por lo tanto no hay relación lineal entre las variables. Así:
# $$
# \text{Cov}(X, Y) = E[XY] - E[X]E[Y] = 0
# $$
#
# ---

# %% [markdown]
# <font color = 'DodgerBlue'>
# <font size = 5>
#
# **Correlación**

# %% [markdown]
# <font color = 'Black'>
# <font size = 3>
#
# - Una **correlación** cercana a $1$ indica una relación lineal fuerte y positiva.
# - Una **correlación** cercana a $-1$ indica una relación lineal fuerte y negativa.
# - Una **correlación** cercana a $0$ indica poca o ninguna relación lineal.

# %% [markdown]
# **Definición Matemática**
#
# La **correlación** estandariza la **covarianza** para que esté entre $-1$ y $1$:
# $$
# \rho_{X,Y} = \frac{\text{Cov}(X, Y)}{\text{Desv}(X) \cdot \text{Desv}(Y)}
# $$
#
# ---

# %% [markdown]
# <font color = 'LightSeaGreen'>
# <font size = 3>
#
# **Ejemplo**
#
# Si $X$ es el tiempo dedicado a estudiar y $Y$ es la calificación obtenida:
#
# - Supongamos que $\text{Cov}(X, Y) = 10$, $\text{Desv}(X) = 2$, y $\text{Desv}(Y) = 5$.
# -
# La correlación es:
#
# $$
# \rho_{X,Y} = \frac{\text{Cov}(X, Y)}{\text{Desv}(X) \cdot \text{Desv}(Y)} = \frac{10}{2 \cdot 5} = 1
# $$
#
# Esto indica una relación perfecta y positiva.
#
# ---

# %% [markdown]
# <font color = 'Brown'>
# <font size = 4>
#
# **Notas**

# %% [markdown]
# <font color = 'DarkRed'>
# <font size = 3>
#
# - $X$ y $Y$:
#
#   Si la **correlación** es cercana a 1, entonces $Y = mX + b$ con $m > 0$.
#
#   Si la **correlación** es cercana a -1, entonces $Y = mX + b$ con $m < 0$.
#
#   Si la **correlación** es cercana a 0, entonces no hay una relación lineal.
#
# - La **covarianza** siempre está en unidades cuadradas.
#
# - La **correlación** no tiene unidades, a diferencia de la **covarianza**.
#
# - Si la **correlación** $\rho_{X,Y} = 0$, esto significa que no hay una relación lineal. Es decir, si grafico las variables $X$ vs $Y$ no voy a observar una línea recta. Pero eso no evita que no observe otra relación. Por ejmeplo, podría observar que $Y = e^{x}$.
#
# - Por otro lado, si $X$ y $Y$ son independientes, entonces la **correlación** $\rho(X,Y) = 0$.
#
# - Si $X$ y $Y$ son **gaussianas** y $\rho(X,Y) = 0$, entonces en este caso sí se cumple que no hay nungún tipo de ralción entre ellas: son **independientes**.
#
# - La **esperanza** es el punto de equilibrio, la **varianza** es qué tanto te alejas de ese punto de equilibrio, la **covarianza** es cómo se relacionan, y la **correlación** es cómo se relacionan linealmente.
#
# - La **correlación** no implica **causalidad**, solo te dice que existe una **relación** lineal, no te está diciendo que una cause a la otra.
#
# - Hay pruebas de **causalidad**!!!
#
# ---

# %% [markdown]
# <font color = 'DodgerBlue'>
# <font size = 5>
#
# **Resumen**

# %% [markdown]
# <font color = 'Black'>
# <font size = 3>
#
# La siguiente tabla resume los conceptos vistos anteriormente.
#
# | Concepto           | Definición Matemática                                     | Explicación Simple                               | Ejemplo                     |
# |---------------------|----------------------------------------------------------|-------------------------------------------------|-----------------------------|
# | **Esperanza**       | $E[X] = \sum x P(X = x)$ o $E[X] = \int x f_X(x) dx$      | El promedio esperado.                           | $E[X] = 1$ para dos monedas.|
# | **Varianza**        | $\text{Var}(X) = E[X^2] - (E[X])^2$                      | Qué tanto se desvían los valores del promedio. | $\text{Var}(X) = 0.5$.      |
# | **Desviación**      | $\text{Desv}(X) = \sqrt{\text{Var}(X)}$                  | Lo mismo que la varianza, pero más intuitivo.   | $\text{Desv}(X) \approx 0.71$. |
# | **Covarianza**      | $\text{Cov}(X, Y) = E[XY] - E[X]E[Y]$                    | Mide si dos variables suben/bajan juntas.       | $\text{Cov}(X, Y) = 0$.     |
# | **Correlación**     | $\rho_{X,Y} = \frac{\text{Cov}(X, Y)}{\text{Desv}(X) \cdot \text{Desv}(Y)}$ | Fuerza de la relación lineal.                  | $\rho_{X,Y} = 1$.           |
#
# ---

# %% [markdown]
# <font color = 'deepskyblue'>
# <font size = 5>
#
# Librerías

# %%
# Importamos las librerías que ocupamos
import pandas as pd
import numpy as np
from plotnine import *
import os
import scipy as sp

# %%
# Obtenemos la ruta del notebook
os.getcwd()
# Out:
# '/home/zick13/Documentos/Developer/Courses/Inferencia_Estadistica/Clases/04_Probabilidades_medidas_va'

# %%
# os.chdir("/home/zick13/Documentos/Developer/Courses/Curso_Inferencia_Estadistica/Clases/04_Probabilidades_medidas_va")

# %% [markdown]
# <font color = 'deepskyblue'>
# <font size = 5>
#
# ---
#
# Lectura de los datos

# %%
# Importamos el data set
caracteristicas = pd.read_csv('Data/caracteristicas.csv')

# %%
# Se muestra el dataframe para ver si cargó de manera exitosa
caracteristicas
# Out:
#      Caracteristica_1  Caracteristica_2  Caracteristica_3  Caracteristica_4  \
# 0           29.787445         91.601190          3.772568      8.640180e+12
# 1           26.545049         82.374847          6.391108      3.375740e+11
# 2           25.076046         78.220452          7.526278      7.769413e+10
# 3           16.518926         50.813128         17.315900      1.493065e+07
# 4           18.123505         54.755894         15.830556      7.429135e+07
# ..                ...               ...               ...               ...
# 108         17.748299         55.899183         12.474095      5.104913e+07
# 109         17.649734         55.795441         14.119061      4.625749e+07
# 110         27.898642         86.577372          4.559915      1.306850e+12
# 111         22.139180         68.062063         10.273426      4.120252e+09
# 112         22.527420         68.019671          7.653685      6.074831e+09
#
#      Caracteristica_5
# 0           15.864695
# ...

# %%
# Imprimimos las primeras 5 filas del data set para verificar si cargaron exitosamente
caracteristicas.head()
# Out:
#    Caracteristica_1  Caracteristica_2  Caracteristica_3  Caracteristica_4  \
# 0         29.787445         91.601190          3.772568      8.640180e+12
# 1         26.545049         82.374847          6.391108      3.375740e+11
# 2         25.076046         78.220452          7.526278      7.769413e+10
# 3         16.518926         50.813128         17.315900      1.493065e+07
# 4         18.123505         54.755894         15.830556      7.429135e+07
#
#    Caracteristica_5
# 0         15.864695
# 1         20.165201
# 2         26.476845
# 3         24.501933
# 4         24.446435

# %%
# Imprimimos las dimensiones del data set (rows, columns)
caracteristicas.shape
# Out:
# (113, 5)

# %%
# Muestra el nombre de las columnas
caracteristicas.columns
# Out:
# Index(['Caracteristica_1', 'Caracteristica_2', 'Caracteristica_3',
#        'Caracteristica_4', 'Caracteristica_5'],
#       dtype='object')

# %%
# Calculamos la correlación entre la característica 1 y la característica 2
sp.stats.pearsonr(caracteristicas["Caracteristica_1"], caracteristicas["Caracteristica_2"])[0]
# Out:
# np.float64(0.9977630043049441)

# %%
# Graficamos la característica 1 y la característica 2 en un Scater plot
ggplot(data=caracteristicas) + geom_point(mapping=aes(x="Caracteristica_1",y="Caracteristica_2"))

# %%
# Calculamos la correlación entre la característica 1 y la característica 3
sp.stats.pearsonr(caracteristicas["Caracteristica_1"], caracteristicas["Caracteristica_3"])[0]
# Out:
# np.float64(-0.9688865461856935)

# %%
# Graficamos la característica 1 y la característica 3 en un Scater plot
ggplot(data=caracteristicas) + geom_point(mapping=aes(x="Caracteristica_1",y="Caracteristica_3"))

# %%
# Calculamos la correlación entre la característica 1 y la característica 4
sp.stats.pearsonr(caracteristicas["Caracteristica_1"], caracteristicas["Caracteristica_4"])[0]
# Out:
# np.float64(0.5643385717130358)

# %%
# Graficamos la característica 1 y la característica 4 en un Scater plot
ggplot(data=caracteristicas) + geom_point(mapping=aes(x="Caracteristica_1",y="Caracteristica_4"))

# %%
# Calculamos la correlación entre la característica 1 y la característica 5
sp.stats.pearsonr(caracteristicas["Caracteristica_1"], caracteristicas["Caracteristica_5"])[0]
# Out:
# np.float64(0.005556315945934275)

# %%
# Graficamos la característica 1 y la característica 5 en un Scater plot
ggplot(data=caracteristicas) + geom_point(mapping=aes(x="Caracteristica_1",y="Caracteristica_5"))
